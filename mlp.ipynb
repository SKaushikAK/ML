# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv('iris_dataset.csv')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df["species"].value_counts()
df["species"].replace({"setosa" : 0, "versicolor" : 1, "virginica" : 2}, inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9096\837422822.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["species"].replace({"setosa" : 0, "versicolor" : 1, "virginica" : 2}, inplace = True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
cor = df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cor, cmap = "Blues", annot = True)
plt.show()

# %%
x = df.drop(columns= ["species"])
y = df["species"]
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size = 0.2)

# %%
model = MLPClassifier (hidden_layer_sizes= (10, 10), max_iter = 1000, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = MLPClassifier (hidden_layer_sizes= (10, 10), max_iter = 1000, random_state = 42)
#
# NameError: name 'MLPClassifier' is not defined

# %%
model.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=1000, random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
score = accuracy_score(y_test, y_pred)

# %%
print(score)
# Out:
# 0.9333333333333333

# %%
mat = confusion_matrix(y_test, y_pred)

sns.heatmap(mat, annot = True, fmt = "d", xticklabels = ["setosa", "versicolor", "virginica"], yticklabels = ["setosa", "versicolor", "virginica"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
